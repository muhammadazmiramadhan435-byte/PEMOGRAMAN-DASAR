# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammadazmiramadhan435-byte/PEMOGRAMAN-DASAR/blob/main/Pertemuan_1_malam_A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Biodata saya

nama ="Muhammad Azmi Ramadhan"
umur = 23
tanggal_lahir = "24-11-2003"
jurusan ="elektro"
alamat ="perumahan rindang garden E3 no 19"
prodi ="TRPE"
semester = 3
matakuliah ="pemograman dasar"
status_lulus = False


print(nama)
print(umur)
print(tanggal_lahir)
print(jurusan)
print(alamat)
print(prodi)
print(semester)
print(matakuliah)
print(status_lulus)
# Out:
# Muhammad Azmi Ramadhan
# 23
# 24-11-2003
# elektro
# perumahan rindang garden E3 no 19
# TRPE
# 3
# pemograman dasar
# False
